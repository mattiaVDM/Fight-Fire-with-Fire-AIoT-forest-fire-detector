# %% [markdown]
# Download the data - after extracting features through a processing block - so we can train a machine learning model.

# %%
import numpy as np
import requests
from keras.callbacks import History 
history = History()

API_KEY = 'ei_93396b8ba0c6af98fbeaf2f8483d323b1b6f7de866f76527b07f66d584dc79bd'

def download_data(url):
    response = requests.get(url, headers={'x-api-key': API_KEY})
    if response.status_code == 200:
        return response.content
    else:
        print(response.content)
        raise ConnectionError('Could not download data file')

X = download_data('https://studio.edgeimpulse.com/v1/api/92758/training/8/x')
Y = download_data('https://studio.edgeimpulse.com/v1/api/92758/training/8/y')
# Out:
# 2022-04-08 09:30:18.389653: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-08 09:30:18.389704: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# Store the data in a temporary file, and load it back through Numpy.

# %%
with open('x_train.npy', 'wb') as file:
    file.write(X)
with open('y_train.npy', 'wb') as file:
    file.write(Y)
X = np.load('x_train.npy')
Y = np.load('y_train.npy')[:,0]

# %% [markdown]
# Define our labels and split the data up in a test and training set:

# %%
import sys, os, random
import tensorflow as tf
from sklearn.model_selection import train_test_split

import logging
tf.get_logger().setLevel(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Set random seeds for repeatable results
RANDOM_SEED = 3
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

classes_values = [ "Fire", "Safe" ]
classes = len(classes_values)

Y = tf.keras.utils.to_categorical(Y - 1, classes)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

input_length = X_train[0].shape[0]

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
validation_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test))

def get_reshape_function(reshape_to):
    def reshape(image, label):
        return tf.reshape(image, reshape_to), label
    return reshape

callbacks = []
# Out:
# 2022-04-08 09:30:54.924314: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-04-08 09:30:54.924368: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-08 09:30:54.924403: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (PC-Matt): /proc/driver/nvidia/version does not exist
# 2022-04-08 09:30:54.924796: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Train the model:

# %%
import math
from pathlib import Path
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Dropout, Conv1D, Flatten, Reshape, MaxPooling1D, BatchNormalization, Conv2D, GlobalMaxPooling2D, Lambda
from tensorflow.keras.optimizers import Adam, Adadelta
from tensorflow.keras.losses import categorical_crossentropy


WEIGHTS_PATH = './transfer-learning-weights/edgeimpulse/MobileNetV2.0_35.96x96.grayscale.bsize_64.lr_0_005.epoch_260.val_loss_3.10.val_accuracy_0.35.hdf5'
# Download the model weights
root_url = 'http://cdn.edgeimpulse.com/'
p = Path(WEIGHTS_PATH)
if not p.exists():
    if not p.parent.exists():
        p.parent.mkdir(parents=True)
    weights = requests.get(root_url + WEIGHTS_PATH[2:]).content
    with open(WEIGHTS_PATH, 'wb') as f:
        f.write(weights)

INPUT_SHAPE = (96, 96, 1)


base_model = tf.keras.applications.MobileNetV2(
    input_shape = INPUT_SHAPE, alpha=0.35,
    weights = WEIGHTS_PATH
)

base_model.trainable = False

model = Sequential()
model.add(InputLayer(input_shape=INPUT_SHAPE, name='x_input'))
# Don't include the base model's top layers
last_layer_index = -3
model.add(Model(inputs=base_model.inputs, outputs=base_model.layers[last_layer_index].output))
model.add(Reshape((-1, model.layers[-1].output.shape[3])))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(classes, activation='softmax'))

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
                loss='categorical_crossentropy',
                metrics=['accuracy'])


# Set the data to the expected input shape
train_dataset = train_dataset.map(get_reshape_function(INPUT_SHAPE), tf.data.experimental.AUTOTUNE)
validation_dataset = validation_dataset.map(get_reshape_function(INPUT_SHAPE), tf.data.experimental.AUTOTUNE)


BATCH_SIZE = 32
train_dataset = train_dataset.batch(BATCH_SIZE, drop_remainder=False)
validation_dataset = validation_dataset.batch(BATCH_SIZE, drop_remainder=False)

history = model.fit(train_dataset, validation_data=validation_dataset, epochs=100, verbose=2, callbacks=callbacks)

print('')
print('Initial training done.', flush=True)

# How many epochs we will fine tune the model
FINE_TUNE_EPOCHS = 10
# What percentage of the base model's layers we will fine tune
FINE_TUNE_PERCENTAGE = 65

print('Fine-tuning model for {} epochs...'.format(FINE_TUNE_EPOCHS), flush=True)

# Determine which layer to begin fine tuning at
model_layer_count = len(model.layers)
fine_tune_from = math.ceil(model_layer_count * ((100 - FINE_TUNE_PERCENTAGE) / 100))

# Allow the entire base model to be trained
model.trainable = True
# Freeze all the layers before the 'fine_tune_from' layer
for layer in model.layers[:fine_tune_from]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.000045),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

model.fit(train_dataset,
                epochs=FINE_TUNE_EPOCHS,
                verbose=2,
                validation_data=validation_dataset,
                callbacks=callbacks,
                class_weight=None
            )
# Out:
# Epoch 1/100
# 83/83 - 6s - loss: 0.4165 - accuracy: 0.8096 - val_loss: 0.3046 - val_accuracy: 0.8803 - 6s/epoch - 70ms/step
# Epoch 2/100
# 83/83 - 2s - loss: 0.2520 - accuracy: 0.8999 - val_loss: 0.2676 - val_accuracy: 0.8879 - 2s/epoch - 24ms/step
# Epoch 3/100
# 83/83 - 2s - loss: 0.2122 - accuracy: 0.9185 - val_loss: 0.2589 - val_accuracy: 0.8955 - 2s/epoch - 23ms/step
# Epoch 4/100
# 83/83 - 2s - loss: 0.1835 - accuracy: 0.9302 - val_loss: 0.2513 - val_accuracy: 0.9030 - 2s/epoch - 25ms/step
# Epoch 5/100
# 83/83 - 2s - loss: 0.1649 - accuracy: 0.9363 - val_loss: 0.2523 - val_accuracy: 0.9045 - 2s/epoch - 24ms/step
# Epoch 6/100
# 83/83 - 2s - loss: 0.1521 - accuracy: 0.9416 - val_loss: 0.2438 - val_accuracy: 0.9121 - 2s/epoch - 27ms/step
# Epoch 7/100
# 83/83 - 2s - loss: 0.1426 - accuracy: 0.9492 - val_loss: 0.2386 - val_accuracy: 0.9091 - 2s/epoch - 24ms/step
# Epoch 8/100
# 83/83 - 2s - loss: 0.1217 - accuracy: 0.9541 - val_loss: 0.2429 - val_accuracy: 0.9121 - 2s/epoch - 24ms/step
# Epoch 9/100
# 83/83 - 2s - loss: 0.1095 - accuracy: 0.9590 - val_loss: 0.2447 - val_accuracy: 0.9212 - 2s/epoch - 23ms/step
# Epoch 10/100
# 83/83 - 2s - loss: 0.1124 - accuracy: 0.9556 - val_loss: 0.2565 - val_accuracy: 0.9106 - 2s/epoch - 25ms/step
# Epoch 11/100
# 83/83 - 2s - loss: 0.0962 - accuracy: 0.9670 - val_loss: 0.2393 - val_accuracy: 0.9167 - 2s/epoch - 26ms/step
# Epoch 12/100
# 83/83 - 2s - loss: 0.0914 - accuracy: 0.9655 - val_loss: 0.2552 - val_accuracy: 0.9227 - 2s/epoch - 26ms/step
# Epoch 13/100
# 83/83 - 2s - loss: 0.0770 - accuracy: 0.9727 - val_loss: 0.2650 - val_accuracy: 0.9197 - 2s/epoch - 24ms/step
# Epoch 14/100
# 83/83 - 2s - loss: 0.0745 - accuracy: 0.9735 - val_loss: 0.2690 - val_accuracy: 0.9197 - 2s/epoch - 25ms/step
# Epoch 15/100
# 83/83 - 2s - loss: 0.0658 - accuracy: 0.9784 - val_loss: 0.2635 - val_accuracy: 0.9227 - 2s/epoch - 23ms/step
# Epoch 16/100
# 83/83 - 2s - loss: 0.0643 - accuracy: 0.9765 - val_loss: 0.2779 - val_accuracy: 0.9227 - 2s/epoch - 25ms/step
# Epoch 17/100
# 83/83 - 2s - loss: 0.0602 - accuracy: 0.9788 - val_loss: 0.2765 - val_accuracy: 0.9258 - 2s/epoch - 24ms/step
# Epoch 18/100
# 83/83 - 2s - loss: 0.0531 - accuracy: 0.9829 - val_loss: 0.2874 - val_accuracy: 0.9303 - 2s/epoch - 24ms/step
# Epoch 19/100
# 83/83 - 2s - loss: 0.0486 - accuracy: 0.9852 - val_loss: 0.2963 - val_accuracy: 0.9258 - 2s/epoch - 26ms/step
# Epoch 20/100
# 83/83 - 2s - loss: 0.0479 - accuracy: 0.9871 - val_loss: 0.2964 - val_accuracy: 0.9303 - 2s/epoch - 24ms/step
# Epoch 21/100
# 83/83 - 2s - loss: 0.0451 - accuracy: 0.9852 - val_loss: 0.3101 - val_accuracy: 0.9318 - 2s/epoch - 23ms/step
# Epoch 22/100
# 83/83 - 2s - loss: 0.0369 - accuracy: 0.9890 - val_loss: 0.3035 - val_accuracy: 0.9303 - 2s/epoch - 26ms/step
# Epoch 23/100
# 83/83 - 2s - loss: 0.0464 - accuracy: 0.9833 - val_loss: 0.3093 - val_accuracy: 0.9242 - 2s/epoch - 23ms/step
# Epoch 24/100
# 83/83 - 2s - loss: 0.0347 - accuracy: 0.9886 - val_loss: 0.3119 - val_accuracy: 0.9303 - 2s/epoch - 24ms/step
# Epoch 25/100
# 83/83 - 2s - loss: 0.0354 - accuracy: 0.9890 - val_loss: 0.3415 - val_accuracy: 0.9318 - 2s/epoch - 24ms/step
# Epoch 26/100
# 83/83 - 2s - loss: 0.0346 - accuracy: 0.9890 - val_loss: 0.3038 - val_accuracy: 0.9303 - 2s/epoch - 23ms/step
# Epoch 27/100
# 83/83 - 2s - loss: 0.0308 - accuracy: 0.9901 - val_loss: 0.3406 - val_accuracy: 0.9303 - 2s/epoch - 23ms/step
# Epoch 28/100
# 83/83 - 2s - loss: 0.0295 - accuracy: 0.9913 - val_loss: 0.3546 - val_accuracy: 0.9197 - 2s/epoch - 24ms/step
# Epoch 29/100
# 83/83 - 2s - loss: 0.0263 - accuracy: 0.9932 - val_loss: 0.3915 - val_accuracy: 0.9136 - 2s/epoch - 23ms/step
# Epoch 30/100
# 83/83 - 2s - loss: 0.0307 - accuracy: 0.9913 - val_loss: 0.3664 - val_accuracy: 0.9182 - 2s/epoch - 24ms/step
# Epoch 31/100
# 83/83 - 2s - loss: 0.0220 - accuracy: 0.9943 - val_loss: 0.3538 - val_accuracy: 0.9182 - 2s/epoch - 24ms/step
# Epoch 32/100
# 83/83 - 2s - loss: 0.0205 - accuracy: 0.9958 - val_loss: 0.3987 - val_accuracy: 0.9212 - 2s/epoch - 24ms/step
# Epoch 33/100
# 83/83 - 2s - loss: 0.0234 - accuracy: 0.9913 - val_loss: 0.4428 - val_accuracy: 0.9091 - 2s/epoch - 23ms/step
# Epoch 34/100
# 83/83 - 2s - loss: 0.0155 - accuracy: 0.9973 - val_loss: 0.4342 - val_accuracy: 0.9197 - 2s/epoch - 24ms/step
# Epoch 35/100
# 83/83 - 3s - loss: 0.0144 - accuracy: 0.9973 - val_loss: 0.3688 - val_accuracy: 0.9182 - 3s/epoch - 31ms/step
# Epoch 36/100
# 83/83 - 2s - loss: 0.0173 - accuracy: 0.9947 - val_loss: 0.3571 - val_accuracy: 0.9273 - 2s/epoch - 25ms/step
# Epoch 37/100
# 83/83 - 2s - loss: 0.0168 - accuracy: 0.9962 - val_loss: 0.3839 - val_accuracy: 0.9318 - 2s/epoch - 24ms/step
# Epoch 38/100
# 83/83 - 2s - loss: 0.0107 - accuracy: 0.9981 - val_loss: 0.4317 - val_accuracy: 0.9242 - 2s/epoch - 24ms/step
# Epoch 39/100
# 83/83 - 2s - loss: 0.0130 - accuracy: 0.9973 - val_loss: 0.4306 - val_accuracy: 0.9197 - 2s/epoch - 23ms/step
# Epoch 40/100
# 83/83 - 2s - loss: 0.0154 - accuracy: 0.9962 - val_loss: 0.4238 - val_accuracy: 0.9167 - 2s/epoch - 24ms/step
# Epoch 41/100
# 83/83 - 2s - loss: 0.0117 - accuracy: 0.9973 - val_loss: 0.4258 - val_accuracy: 0.9182 - 2s/epoch - 24ms/step
# Epoch 42/100
# 83/83 - 2s - loss: 0.0153 - accuracy: 0.9970 - val_loss: 0.4809 - val_accuracy: 0.9091 - 2s/epoch - 23ms/step
# Epoch 43/100
# 83/83 - 2s - loss: 0.0199 - accuracy: 0.9924 - val_loss: 0.4299 - val_accuracy: 0.9091 - 2s/epoch - 23ms/step
# Epoch 44/100
# 83/83 - 2s - loss: 0.0150 - accuracy: 0.9966 - val_loss: 0.5088 - val_accuracy: 0.9121 - 2s/epoch - 21ms/step
# Epoch 45/100
# 83/83 - 2s - loss: 0.0144 - accuracy: 0.9962 - val_loss: 0.4834 - val_accuracy: 0.9197 - 2s/epoch - 22ms/step
# Epoch 46/100
# 83/83 - 2s - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.4325 - val_accuracy: 0.9303 - 2s/epoch - 22ms/step
# Epoch 47/100
# 83/83 - 2s - loss: 0.0154 - accuracy: 0.9947 - val_loss: 0.4416 - val_accuracy: 0.9227 - 2s/epoch - 23ms/step
# Epoch 48/100
# 83/83 - 2s - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.4718 - val_accuracy: 0.9091 - 2s/epoch - 21ms/step
# Epoch 49/100
# 83/83 - 2s - loss: 0.0130 - accuracy: 0.9951 - val_loss: 0.4415 - val_accuracy: 0.9242 - 2s/epoch - 22ms/step
# Epoch 50/100
# 83/83 - 2s - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.4977 - val_accuracy: 0.9212 - 2s/epoch - 22ms/step
# Epoch 51/100
# 83/83 - 2s - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.4969 - val_accuracy: 0.9212 - 2s/epoch - 22ms/step
# Epoch 52/100
# 83/83 - 2s - loss: 0.0102 - accuracy: 0.9973 - val_loss: 0.4740 - val_accuracy: 0.9182 - 2s/epoch - 23ms/step
# Epoch 53/100
# 83/83 - 2s - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.4972 - val_accuracy: 0.9258 - 2s/epoch - 23ms/step
# Epoch 54/100
# 83/83 - 2s - loss: 0.0063 - accuracy: 0.9989 - val_loss: 0.4795 - val_accuracy: 0.9242 - 2s/epoch - 22ms/step
# Epoch 55/100
# 83/83 - 2s - loss: 0.0089 - accuracy: 0.9977 - val_loss: 0.4411 - val_accuracy: 0.9212 - 2s/epoch - 23ms/step
# Epoch 56/100
# 83/83 - 2s - loss: 0.0075 - accuracy: 0.9985 - val_loss: 0.4779 - val_accuracy: 0.9273 - 2s/epoch - 22ms/step
# Epoch 57/100
# 83/83 - 2s - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.4735 - val_accuracy: 0.9242 - 2s/epoch - 24ms/step
# Epoch 58/100
# 83/83 - 2s - loss: 0.0095 - accuracy: 0.9981 - val_loss: 0.4563 - val_accuracy: 0.9227 - 2s/epoch - 22ms/step
# Epoch 59/100
# 83/83 - 2s - loss: 0.0083 - accuracy: 0.9970 - val_loss: 0.5181 - val_accuracy: 0.9227 - 2s/epoch - 22ms/step
# Epoch 60/100
# 83/83 - 2s - loss: 0.0089 - accuracy: 0.9966 - val_loss: 0.4434 - val_accuracy: 0.9303 - 2s/epoch - 22ms/step
# Epoch 61/100
# 83/83 - 2s - loss: 0.0073 - accuracy: 0.9989 - val_loss: 0.4933 - val_accuracy: 0.9288 - 2s/epoch - 21ms/step
# Epoch 62/100
# 83/83 - 2s - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.4667 - val_accuracy: 0.9288 - 2s/epoch - 22ms/step
# Epoch 63/100
# 83/83 - 2s - loss: 0.0076 - accuracy: 0.9985 - val_loss: 0.5083 - val_accuracy: 0.9227 - 2s/epoch - 23ms/step
# Epoch 64/100
# 83/83 - 2s - loss: 0.0183 - accuracy: 0.9936 - val_loss: 0.5459 - val_accuracy: 0.9227 - 2s/epoch - 22ms/step
# Epoch 65/100
# 83/83 - 2s - loss: 0.0049 - accuracy: 0.9996 - val_loss: 0.4723 - val_accuracy: 0.9273 - 2s/epoch - 22ms/step
# Epoch 66/100
# 83/83 - 2s - loss: 0.0079 - accuracy: 0.9989 - val_loss: 0.4937 - val_accuracy: 0.9258 - 2s/epoch - 23ms/step
# Epoch 67/100
# 83/83 - 2s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.4804 - val_accuracy: 0.9273 - 2s/epoch - 23ms/step
# Epoch 68/100
# 83/83 - 2s - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.4664 - val_accuracy: 0.9318 - 2s/epoch - 22ms/step
# Epoch 69/100
# 83/83 - 2s - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.5243 - val_accuracy: 0.9242 - 2s/epoch - 22ms/step
# Epoch 70/100
# 83/83 - 2s - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.4753 - val_accuracy: 0.9303 - 2s/epoch - 23ms/step
# Epoch 71/100
# 83/83 - 2s - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.4538 - val_accuracy: 0.9288 - 2s/epoch - 22ms/step
# Epoch 72/100
# 83/83 - 2s - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.5004 - val_accuracy: 0.9288 - 2s/epoch - 23ms/step
# Epoch 73/100
# 83/83 - 2s - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.5490 - val_accuracy: 0.9303 - 2s/epoch - 22ms/step
# Epoch 74/100
# 83/83 - 2s - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.5146 - val_accuracy: 0.9273 - 2s/epoch - 22ms/step
# Epoch 75/100
# 83/83 - 2s - loss: 0.0071 - accuracy: 0.9985 - val_loss: 0.5396 - val_accuracy: 0.9288 - 2s/epoch - 21ms/step
# Epoch 76/100
# 83/83 - 2s - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.5153 - val_accuracy: 0.9303 - 2s/epoch - 21ms/step
# Epoch 77/100
# 83/83 - 2s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5506 - val_accuracy: 0.9303 - 2s/epoch - 22ms/step
# Epoch 78/100
# 83/83 - 2s - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.4918 - val_accuracy: 0.9288 - 2s/epoch - 21ms/step
# Epoch 79/100
# 83/83 - 2s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.9303 - 2s/epoch - 21ms/step
# Epoch 80/100
# 83/83 - 2s - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.5386 - val_accuracy: 0.9197 - 2s/epoch - 22ms/step
# Epoch 81/100
# 83/83 - 2s - loss: 0.0101 - accuracy: 0.9954 - val_loss: 0.4657 - val_accuracy: 0.9197 - 2s/epoch - 21ms/step
# Epoch 82/100
# 83/83 - 2s - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.5175 - val_accuracy: 0.9258 - 2s/epoch - 23ms/step
# Epoch 83/100
# 83/83 - 2s - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.5060 - val_accuracy: 0.9227 - 2s/epoch - 22ms/step
# Epoch 84/100
# 83/83 - 2s - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.5078 - val_accuracy: 0.9258 - 2s/epoch - 22ms/step
# Epoch 85/100
# 83/83 - 2s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5227 - val_accuracy: 0.9379 - 2s/epoch - 22ms/step
# Epoch 86/100
# 83/83 - 2s - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.5664 - val_accuracy: 0.9333 - 2s/epoch - 23ms/step
# Epoch 87/100
# 83/83 - 2s - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.5595 - val_accuracy: 0.9333 - 2s/epoch - 23ms/step
# Epoch 88/100
# 83/83 - 2s - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.4153 - val_accuracy: 0.9364 - 2s/epoch - 22ms/step
# Epoch 89/100
# 83/83 - 2s - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.4897 - val_accuracy: 0.9288 - 2s/epoch - 22ms/step
# Epoch 90/100
# 83/83 - 2s - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.5501 - val_accuracy: 0.9273 - 2s/epoch - 23ms/step
# Epoch 91/100
# 83/83 - 2s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5572 - val_accuracy: 0.9288 - 2s/epoch - 21ms/step
# Epoch 92/100
# 83/83 - 2s - loss: 0.0056 - accuracy: 0.9989 - val_loss: 0.5833 - val_accuracy: 0.9288 - 2s/epoch - 23ms/step
# Epoch 93/100
# 83/83 - 2s - loss: 0.0049 - accuracy: 0.9973 - val_loss: 0.5762 - val_accuracy: 0.9227 - 2s/epoch - 22ms/step
# Epoch 94/100
# 83/83 - 2s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5328 - val_accuracy: 0.9273 - 2s/epoch - 21ms/step
# Epoch 95/100
# 83/83 - 2s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.5668 - val_accuracy: 0.9333 - 2s/epoch - 23ms/step
# Epoch 96/100
# 83/83 - 2s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6142 - val_accuracy: 0.9303 - 2s/epoch - 21ms/step
# Epoch 97/100
# 83/83 - 2s - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.5858 - val_accuracy: 0.9273 - 2s/epoch - 22ms/step
# Epoch 98/100
# 83/83 - 2s - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.5581 - val_accuracy: 0.9303 - 2s/epoch - 22ms/step
# Epoch 99/100
# 83/83 - 2s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5372 - val_accuracy: 0.9242 - 2s/epoch - 21ms/step
# Epoch 100/100
# 83/83 - 2s - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.5075 - val_accuracy: 0.9318 - 2s/epoch - 26ms/step
#
# Initial training done.
# Fine-tuning model for 10 epochs...
# Epoch 1/10
# 83/83 - 4s - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.5078 - val_accuracy: 0.9318 - 4s/epoch - 50ms/step
# Epoch 2/10
# 83/83 - 2s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5083 - val_accuracy: 0.9318 - 2s/epoch - 22ms/step
# Epoch 3/10
# 83/83 - 2s - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.5086 - val_accuracy: 0.9318 - 2s/epoch - 21ms/step
# Epoch 4/10
# 83/83 - 2s - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.5089 - val_accuracy: 0.9318 - 2s/epoch - 22ms/step
# Epoch 5/10
# 83/83 - 2s - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.5091 - val_accuracy: 0.9318 - 2s/epoch - 21ms/step
# Epoch 6/10
# 83/83 - 2s - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.5093 - val_accuracy: 0.9318 - 2s/epoch - 21ms/step
# Epoch 7/10
# 83/83 - 2s - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.5097 - val_accuracy: 0.9318 - 2s/epoch - 21ms/step
# Epoch 8/10
# 83/83 - 2s - loss: 0.0042 - accuracy: 0.9996 - val_loss: 0.5103 - val_accuracy: 0.9318 - 2s/epoch - 21ms/step
# Epoch 9/10
# 83/83 - 2s - loss: 0.0035 - accuracy: 0.9996 - val_loss: 0.5104 - val_accuracy: 0.9318 - 2s/epoch - 21ms/step
# Epoch 10/10
# 83/83 - 2s - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.5107 - val_accuracy: 0.9318 - 2s/epoch - 21ms/step

# %%
# Save the model to disk
model.save('saved_model')
# Out:
# 2022-04-08 09:34:47.305859: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.

# %%
import keras
from matplotlib import pyplot as plt

loss=history.history['loss']
loss=loss[:200]
plt.plot(loss)
val_loss=history.history['val_loss']
val_loss=val_loss[:200]
plt.plot(val_loss)



plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

acc=history.history['accuracy']
acc=acc[:200]
plt.plot(acc)
vacc=history.history['val_accuracy']
vacc=vacc[:200]
plt.plot(vacc)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()
